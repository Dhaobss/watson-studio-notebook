# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Dhia Ben Sassi**   student

# %% [markdown]
# *I'm intreseted in data science because of its impact on the process  of strategtic decision making*
# ______________________________________________________________________________________________________

# %% [markdown]
# ### simple math

# %%
(12231321+43123424423)
# Out:
# 43135655744

# %% [markdown]
# * cars
# * breaks
# ***
# __[advanced data science](https://www.coursera.org/specializations/advanced-data-science-ibm)__
#
#
# 1. what is data science
# 2. tools for data science
